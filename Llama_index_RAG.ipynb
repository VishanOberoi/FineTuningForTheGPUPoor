# %% [markdown]
# <a href="https://colab.research.google.com/github/VishanOberoi/FineTuningForTheGPUPoor/blob/main/Llama_index_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama-index
# !pip install -q transformers einops accelerate langchain bitsandbytes
# !pip install install sentence_transformers
# !pip install llama-index-llms-huggingface
# !pip install llama-index-embeddings-huggingface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 59.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from llama_index.core import VectorStoreIndex,SimpleDirectoryReader,ServiceContext,PromptTemplate
from llama_index.llms.huggingface import HuggingFaceLLM

# %%
documents = SimpleDirectoryReader("/content/data").load_data()

# %%
system_prompt = '''As a chatbot for the Company Maitri Lab Grown Diamonds, your primary focus is to provide concise, accurate and helpful information based on the context provided, about the company Maitri Lab Grown diamonds and the diamond industry. Engage in discussions related to diamonds, including sourcing, types, and care, as well as information specific to Maitri Diamonds. When asked about unrelated topics, politely redirect the conversation to the company, your areas of expertise or inform the user that the topic falls outside your scope. Maintain a professional and neutral tone, respecting all viewpoints and ensuring accuracy in your responses.'''

## Default format supportable by LLama2
query_wrapper_prompt=PromptTemplate("<|USER|>{query_str}<|ASSISTANT|>")

# %%
system_prompt = 'You are a chatbot that provides information on Jainism based on the book provided: Encyclopedia of Jain Religion. Give short responses, be humble and speak dont engage in coversation outside of Jainisim and redirect an irrelevant conversation to Jainism. '
## Default format supportable by LLama2
query_wrapper_prompt=PromptTemplate("<|USER|>{query_str}<|ASSISTANT|>")

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
import torch
import torch
import logging
import sys
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding



logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.2, "top_k":40, "top_p":0.6, "length_penalty":1,},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="vishanoberoi/Llama-2-7b-chat-hf-fine-tuned",
    device_map="auto",
    # uncomment this if using CUDA to reduce memory usage
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)



Settings.chunk_size = 512
Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-mpnet-base-v2", max_length=256)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9b33cbdadd66> in <cell line: 13>()
#      11 logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))
#      12
# ---> 13 llm = HuggingFaceLLM(
#      14     context_window=4096,
#      15     max_new_tokens=256,
#
# ...

# %%
import torch
import torch
import logging
import sys
from llama_index.core import Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding



logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.2, "top_k":40, "top_p":0.6, "length_penalty":1,},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    # uncomment this if using CUDA to reduce memory usage
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)



Settings.chunk_size = 512
Settings.llm = llm
Settings.embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-mpnet-base-v2", max_length=256)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Who are you")
response.print_response_stream()
# Out:
# I am an AI assistant trained to provide information on Jainism based on the book "Encyclopedia of Jain Religion". My purpose is to provide accurate and helpful responses to your questions about Jainism. I am here to help you learn more about this ancient religion and its beliefs. Please feel free to ask me anything.</s>

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("What is tittaraya")
response.print_response_stream()
# Out:
# Tittaraya is a term used in Jainism to refer to a Tirthankara, which is a spiritual teacher or guru who creates a "shore" or path beyond the ocean of suffering (bhavasagara) in the form of "dharamtirtha." Tirthankaras are believed to be born in two stages of time, the first stage being the happiest and the last stage being the most unhappy. According to Jain belief, Tirthankaras are not incarnations of God but rather souls who have achieved Kevalajnana or omniscience through rigorous penance and spiritual practices. They possess special qualities of the head and heart and are considered the path finders who guide souls towards liberation from the cycle of birth and death.</s>

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Who ")
response.print_response_stream()
# Out:
# According to Jain belief, Jains are subject to two endless temporal cycles: the Samsara and the Avasarpani. The Samsara cycle is the cycle of birth, death, and rebirth, where souls are trapped in a cycle of suffering and ignorance. The Avasarpani cycle is the cycle of the last Tirthankara, Mahavira, where souls are freed from the Samsara cycle and attain liberation.</s>

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("How many Jains in India")
response.print_response_stream()
# Out:
# According to the Encyclopedia of Jain Religion, the total number of Jain followers in India is approximately four million.</s>

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Have foreginers been interested in Jainism")
response.print_response_stream()
# Out:
# Yes, foreigners have been interested in Jainism. In fact, the book "Encyclopedia of Jain Religion" is a multi-volume study of this ancient religion, written by various scholars from around the world. The book covers a wide range of Jain religious thought, including the teachings of the Tirthankaras, the philosophy of non-violence, and the history of Jainism. Many foreign scholars have contributed to the study of Jainism, including Colin Mackenzie, Barnett, Dr. F. Buchanan, Dr. H.H. Wilson, Weber, J.G. Buhler, Walther Schubring, Leumann, Winternitz, Guerinot, Hermann Jacobi, Hoernale, Glasenapp, Osborn Martin, and N.R.Guseva. Their research and writings have helped to make Jainism known in the world and to understand its rich tradition and philosophy.</s>

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Which century was Mahavir active in")
response.print_response_stream()
# Out:
# Mahavira was active in the 6th century B.C.</s>

# %%
# !pip install gradio

# %%
def stream(input):
  query_engine = index.as_query_engine()
  response = query_engine.query(input)
  return response

# %%
import gradio as gr

iface = gr.Interface(fn=stream, inputs="text", outputs="text")
iface.launch()

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("What are the different types of diamonds")
response.print_response_stream()

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("What certifications does Maitri have?")
response.print_response_stream()

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Who are you")
response.print_response_stream()

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("Tell me a joke.")
response.print_response_stream()

# %%
query_engine = index.as_query_engine(streaming=True)
response = query_engine.query("How can I contact Maitri Lab grown diamond?")
response.print_response_stream()

# %%
#Making a Chatbot.

# %%
response = query_engine.chat("Oh interesting, tell me more.")
print(response)

# %%
chat_engine = index.as_chat_engine()
streaming_response = chat_engine.stream_chat("Tell me a joke.")
for token in streaming_response.response_gen:
    print(token, end="")
